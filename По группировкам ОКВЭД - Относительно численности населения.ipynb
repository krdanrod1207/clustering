# %%
import pandas as pd
import numpy as np
data = pd.read_excel('По группировкам ОКВЭД - Относительно численности.xls')

# %%
data.head()
# Out:
#    Unnamed: 0                    Unnamed: 1  Численность населения 2017  \
# 0           0          Белгородская область                     1552865
# 1           1              Брянская область                     1220530
# 2           2          Владимирская область                     1389599
# 3           3           Воронежская область                     2335408
# 4           4            Ивановская область                     1023170
#
#    СЕЛЬСКОЕ, ЛЕСНОЕ ХОЗЯЙСТВО, ОХОТА, РЫБОЛОВСТВО И РЫБОВОДСТВО  \
# 0                                            5304071
# 1                                             528413
# 2                                             464416
# 3                                            1492759
# 4                                             170733
#
#    ДОБЫЧА ПОЛЕЗНЫХ ИСКОПАЕМЫХ  ОБРАБАТЫВАЮЩИЕ ПРОИЗВОДСТВА  \
# 0                     7597707                     13068281
# 1                           0                      4883588
# ...

# %%
data_for_clustering = data.drop(columns = 'Unnamed: 1')

# %%
data.drop(columns = 'ГОСУДАРСТВЕННОЕ УПРАВЛЕНИЕ И ОБЕСПЕЧЕНИЕ ВОЕННОЙ БЕЗОПАСНОСТИ; СОЦИАЛЬНОЕ ОБЕСПЕЧЕНИЕ', inplace = True)

# %%
data_for_clustering.head()
# Out:
#    Unnamed: 0  Численность населения 2017  \
# 0           0                     1552865
# 1           1                     1220530
# 2           2                     1389599
# 3           3                     2335408
# 4           4                     1023170
#
#    СЕЛЬСКОЕ, ЛЕСНОЕ ХОЗЯЙСТВО, ОХОТА, РЫБОЛОВСТВО И РЫБОВОДСТВО  \
# 0                                            5304071
# 1                                             528413
# 2                                             464416
# 3                                            1492759
# 4                                             170733
#
#    ДОБЫЧА ПОЛЕЗНЫХ ИСКОПАЕМЫХ  ОБРАБАТЫВАЮЩИЕ ПРОИЗВОДСТВА  \
# 0                     7597707                     13068281
# 1                           0                      4883588
# 2                      316032                     29822757
# 3                      509404                     11670090
# 4                       58171                      2679322
#
# ...

# %%
data_for_clustering.drop(columns = 'Unnamed: 0', inplace = True)

# %%
data_for_clustering.drop(columns = 'ГОСУДАРСТВЕННОЕ УПРАВЛЕНИЕ И ОБЕСПЕЧЕНИЕ ВОЕННОЙ БЕЗОПАСНОСТИ; СОЦИАЛЬНОЕ ОБЕСПЕЧЕНИЕ', inplace = True)

# %%
data_for_clustering.drop(columns = 'nCluster_6', inplace = True)

# %%
data_for_clustering.head()
# Out:
#    Численность населения 2017  \
# 0                     1552865
# 1                     1220530
# 2                     1389599
# 3                     2335408
# 4                     1023170
#
#    СЕЛЬСКОЕ, ЛЕСНОЕ ХОЗЯЙСТВО, ОХОТА, РЫБОЛОВСТВО И РЫБОВОДСТВО  \
# 0                                            5304071
# 1                                             528413
# 2                                             464416
# 3                                            1492759
# 4                                             170733
#
#    ДОБЫЧА ПОЛЕЗНЫХ ИСКОПАЕМЫХ  ОБРАБАТЫВАЮЩИЕ ПРОИЗВОДСТВА  \
# 0                     7597707                     13068281
# 1                           0                      4883588
# 2                      316032                     29822757
# 3                      509404                     11670090
# 4                       58171                      2679322
#
#    ОБЕСПЕЧЕНИЕ ЭЛЕКТРИЧЕСКОЙ ЭНЕРГИЕЙ, ГАЗОМ И ПАРОМ; КОНДИЦИОНИРОВАНИЕ ВОЗДУХА  \
# ...

# %%
data_for_clustering['СЕЛЬСКОЕ, ЛЕСНОЕ ХОЗЯЙСТВО, ОХОТА, РЫБОЛОВСТВО И РЫБОВОДСТВО'] = data_for_clustering['СЕЛЬСКОЕ, ЛЕСНОЕ ХОЗЯЙСТВО, ОХОТА, РЫБОЛОВСТВО И РЫБОВОДСТВО'] / data_for_clustering['Численность населения 2017']

# %%
data_for_clustering.head()
# Out:
#    Численность населения 2017  \
# 0                     1552865
# 1                     1220530
# 2                     1389599
# 3                     2335408
# 4                     1023170
#
#    СЕЛЬСКОЕ, ЛЕСНОЕ ХОЗЯЙСТВО, ОХОТА, РЫБОЛОВСТВО И РЫБОВОДСТВО  \
# 0                                            5304071
# 1                                             528413
# 2                                             464416
# 3                                            1492759
# 4                                             170733
#
#    ДОБЫЧА ПОЛЕЗНЫХ ИСКОПАЕМЫХ  ОБРАБАТЫВАЮЩИЕ ПРОИЗВОДСТВА  \
# 0                     7597707                     13068281
# 1                           0                      4883588
# 2                      316032                     29822757
# 3                      509404                     11670090
# 4                       58171                      2679322
#
#    ОБЕСПЕЧЕНИЕ ЭЛЕКТРИЧЕСКОЙ ЭНЕРГИЕЙ, ГАЗОМ И ПАРОМ; КОНДИЦИОНИРОВАНИЕ ВОЗДУХА  \
# ...

# %%
data_for_clustering = pd.DataFrame(df1.values/ df2.values, columns=df1.columns)
data_for_clustering.drop(columns = 'Численность населения 2017', inplace = True)

# %%
import pandas as pd
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import *
from matplotlib import pyplot as plt
from matplotlib import rc
import numpy as np
from sklearn.cluster import KMeans
#данная строчка нужна для корректного отображения графиков
# %matplotlib inline 
from sklearn import preprocessing
dataNorm = preprocessing.scale(data_for_clustering)

# %%
data_dist = pdist(dataNorm, 'euclidean')
data_linkage = linkage(data_dist, method='average')

# %%
last = data_linkage[-10:, 2]
last_rev = last[::-1]
idxs = np.arange(1, len(last) + 1)
plt.plot(idxs, last_rev)

acceleration = np.diff(last, 2)  
acceleration_rev = acceleration[::-1]
plt.plot(idxs[:-2] + 1, acceleration_rev)
plt.show()
k = acceleration_rev.argmax() + 2 
print("clusters:", k)
# Out:
# clusters: 3

# %%
def fancy_dendrogram(*args, **kwargs):
    max_d = kwargs.pop('max_d', None)
    if max_d and 'color_threshold' not in kwargs:
        kwargs['color_threshold'] = max_d
    annotate_above = kwargs.pop('annotate_above', 0)

    ddata = dendrogram(*args, **kwargs)

    if not kwargs.get('no_plot', False):
        plt.title('Hierarchical Clustering Dendrogram (truncated)')
        plt.xlabel('sample index or (cluster size)')
        plt.ylabel('distance')
        for i, d, c in zip(ddata['icoord'], ddata['dcoord'], ddata['color_list']):
            x = 0.5 * sum(i[1:3])
            y = d[1]
            if y > annotate_above:
                plt.plot(x, y, 'o', c=c)
                plt.annotate("%.3g" % y, (x, y), xytext=(0, -5),
                             textcoords='offset points',
                             va='top', ha='center')
        if max_d:
            plt.axhline(y=max_d, c='k')
    return ddata

# %%
nCluster=6
#строим дендрограмму 
fancy_dendrogram(
    data_linkage,
    truncate_mode='lastp',
    p=nCluster, 
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,
)
plt.show()

# %%
km = KMeans(n_clusters=6).fit(dataNorm)

# %%
km.labels_ +1
# Out:
# array([3, 3, 3, 3, 3, 1, 3, 3, 1, 3, 3, 3, 3, 3, 1, 3, 3, 1, 3, 3, 3, 1,
#        3, 1, 5, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 1,
#        3, 3, 1, 3, 1, 3, 3, 3, 3, 3, 3, 1, 1, 3, 1, 3, 3, 3, 3, 3, 1, 3,
#        1, 1, 1, 4, 3, 2, 1, 3, 3, 3, 3, 3, 6])

# %%
data_for_clustering['nCluster_6'] = km.labels_ +1

# %%
data_for_clustering['nCluster_6'].value_counts()
# Out:
# 1    49
# 6    18
# 4     8
# 2     2
# 5     1
# 3     1
# Name: nCluster_6, dtype: int64

# %%
data_for_clustering.head()
# Out:
#    СЕЛЬСКОЕ, ЛЕСНОЕ ХОЗЯЙСТВО, ОХОТА, РЫБОЛОВСТВО И РЫБОВОДСТВО  \
# 0                                           3.415668
# 1                                           0.432937
# 2                                           0.334209
# 3                                           0.639186
# 4                                           0.166867
#
#    ДОБЫЧА ПОЛЕЗНЫХ ИСКОПАЕМЫХ  ОБРАБАТЫВАЮЩИЕ ПРОИЗВОДСТВА  \
# 0                    4.892703                     8.415594
# 1                    0.000000                     4.001203
# 2                    0.227427                    21.461412
# 3                    0.218122                     4.997024
# 4                    0.056854                     2.618648
#
#    ОБЕСПЕЧЕНИЕ ЭЛЕКТРИЧЕСКОЙ ЭНЕРГИЕЙ, ГАЗОМ И ПАРОМ; КОНДИЦИОНИРОВАНИЕ ВОЗДУХА  \
# 0                                           5.383879
# 1                                           1.400903
# 2                                           3.548888
# ...

# %%
km = KMeans(n_clusters=3).fit(dataNorm)

# %%
km.labels_ +1
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 3, 2,
#        3, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 3])

# %%
data_for_clustering['nCluster_3'] = km.labels_ +1

# %%
data_for_clustering.head()
# Out:
#    СЕЛЬСКОЕ, ЛЕСНОЕ ХОЗЯЙСТВО, ОХОТА, РЫБОЛОВСТВО И РЫБОВОДСТВО  \
# 0                                           3.415668
# 1                                           0.432937
# 2                                           0.334209
# 3                                           0.639186
# 4                                           0.166867
#
#    ДОБЫЧА ПОЛЕЗНЫХ ИСКОПАЕМЫХ  ОБРАБАТЫВАЮЩИЕ ПРОИЗВОДСТВА  \
# 0                    4.892703                     8.415594
# 1                    0.000000                     4.001203
# 2                    0.227427                    21.461412
# 3                    0.218122                     4.997024
# 4                    0.056854                     2.618648
#
#    ОБЕСПЕЧЕНИЕ ЭЛЕКТРИЧЕСКОЙ ЭНЕРГИЕЙ, ГАЗОМ И ПАРОМ; КОНДИЦИОНИРОВАНИЕ ВОЗДУХА  \
# 0                                           5.383879
# 1                                           1.400903
# 2                                           3.548888
# ...

# %%
data_for_clustering['nCluster_3'].value_counts()
# Out:
# 2    71
# 3     7
# 1     1
# Name: nCluster_3, dtype: int64
